# %%
dbutils.widgets.removeAll()

# %%
dbutils.widgets.text("storageName", "adlsssmartdata2698")
dbutils.widgets.text("catalogo", "catalog_au")

# %%
storageName = dbutils.widgets.get("storageName")
catalogo = dbutils.widgets.get("catalogo")

# %% [markdown]
# External Location

# %%
# %sql
DROP EXTERNAL LOCATION IF EXISTS `exlt-metastore` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `exlt-raw` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `exlt-bronze` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `exlt-silver` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `exlt-golden` FORCE;

# %% [markdown]
# Catalogo

# %%
# %sql
DROP CATALOG IF EXISTS catalog_au CASCADE;

# %% [markdown]
# Esquemas

# %%
# %sql
DROP SCHEMA IF EXISTS catalog_au.raw;
DROP SCHEMA IF EXISTS catalog_au.bronze;
DROP SCHEMA IF EXISTS catalog_au.silver;
DROP SCHEMA IF EXISTS catalog_au.golden;

# %% [markdown]
# Tablas bronze

# %%
# %sql
DROP TABLE IF EXISTS catalog_au.bronze.orders_raw;
DROP TABLE IF EXISTS catalog_au.bronze.customers_raw;
DROP TABLE IF EXISTS catalog_au.bronze.order_items_raw;
DROP TABLE IF EXISTS catalog_au.bronze.products_raw;
DROP TABLE IF EXISTS catalog_au.bronze.payments_raw;
DROP TABLE IF EXISTS catalog_au.bronze.category_translation_raw;

# %% [markdown]
# Tablas silver

# %%
# %sql
DROP TABLE IF EXISTS catalog_au.silver.olist_orders_enriched;

# %% [markdown]
# Tablas golden

# %%
# %sql
DROP TABLE IF EXISTS catalog_au.golden.olist_sales_summary;

# %% [markdown]
# Rutas físicas

# %%
# %python
#dbutils.fs.rm(f"abfss://bronze@{storageName}.dfs.core.windows.net/",True)
#dbutils.fs.rm(f"abfss://silver@{storageName}.dfs.core.windows.net/",True)
#dbutils.fs.rm(f"abfss://golden@{storageName}.dfs.core.windows.net/",True)
